# %%
import json 
import regex as re

# %%
with open('../poems.txt', 'r', encoding='utf-8') as poem_file:
    poems = poem_file.read().replace('\xa0', ' ') #replaces non-breaking spaces as normal spaces

# %%
poems
# Out:
# 'Ricardo Reis\nDiana através dos ramos\n\nDiana através dos ramos\nEspreita a vinda de Endymion\nEndymion que nunca vem,\nEndymion, Endymion,\nLá longe na floresta…\nE a sua voz chamando\nExclama através dos ramos\nEndymion, Endymion…\n\nAssim choram os deuses…\n\n\nRicardo Reis\nAqui, sem outro Apolo do que Apolo,\n\nAqui, sem outro Apolo do que Apolo,\nSem um suspiro abandonemos Cristo\n        E a febre de buscarmos\n        Um deus dos dualismos.\n\nE longe da cristã sensualidade\nQue a casta calma da beleza antiga\n        Nos restitua o antigo\n        Sentimento da vida.\n\n\nRicardo Reis\nEm Ceres anoitece.\n\nEm Ceres anoitece.\nNos píncaros ainda\n        Faz luz.\n\nSinto-me tão grande\nNesta hora solene\n        E vã\n\nQue, assim como há deuses\nDos campos, das flores\n        Das searas,\n\n\nAgora eu quisera\nQue um deus existisse\n        De mim.\n\n\nRicardo Reis\nNão a ti, mas aos teus, odeio, Cristo.\n\nNão a ti, mas aos teus, odeio, Cristo.\nTu não és mais que um deus a mais no eterno\n        Pantéon que preside\n        À nossa vida incerta.\n\nNem maior nem menor que os novos deuses,\nTua sombria forma dolorida\n        Trouxe algo que faltava\n        Ao número dos divos.\n\nPor isso reina a par de outros no Olimpo,\nOu pela triste terra se quiseres\n        Vai enxugar o pranto\n        Dos humanos que sofrem.\n\nNão venham, porém, estultos teus cultores\nEm teu nome vedar o eterno culto\n        Das presenças maiores\n        E parceiras da tua.\n\nA esses, sim, do âmago eu odeio\nDo crente peito, e a esses eu não sigo,\n        Supersticiosos leigos\n        Na ciência dos deuses.\n\nAh, aumentai, não combatendo nunca.\nEnriquecei o Olimpo, aos deuses dando\n        Cada vez maior força\n        Plo número maior.\n\nBasta os males que o Fado as Parcas fez\nPor seu intuito natural fazerem.\n        Nós homens nos façamos\n        Unidos pelos deuses.\n\n\nFernando Pessoa\nO burburinho da água\n\nO burburinho da água\n\nO burburinho da água\nNo regato que se espalha\nÉ como a ilusão que é mágoa\nQuando a verdade a baralha.\n\n\nRicardo Reis\nSofro, Lídia, do medo do destino. [1]\n\nSofro, Lídia, do medo do destino.\nQualquer pequena cousa de onde pode\nBrotar uma ordem nova em minha vida,\n        Lídia, me aterra.\nQualquer cousa, qual seja, que transforme\nMeu plano curso de existência, embora\nPara melhores cousas o transforme,\n        Por transformar\nOdeio, e não o quero. Os deuses dessem\nQue ininterrupta minha vida fosse\nUma planície sem relevos, indo\n        Até ao fim.\nA glória embora eu nunca haurisse, ou nunca\nAmor ou justa estima dessem-me outros,\nBasta que a vida seja só a vida\n        E que eu a viva. \n\n\nFernando Pessoa\nLeve sonho, vais no chão\n\nLeve sonho, vais no chão\n\nLeve sonho, vais no chão\nA andares sem teres ser.\nÉs como o meu coração\nQue sente sem nada ter.\n\n\nÁlvaro de Campos\nANIVERSÁRIO\n\nANIVERSÁRIO\n\nNo tempo em que festejavam o dia dos meus anos, \nEu era feliz e ninguém estava morto. \nNa casa antiga, até eu fazer anos era uma tradição de há séculos, \nE a alegria de todos, e a minha, estava certa com uma religião qualquer. \n\nNo tempo em que festejavam o dia dos meus anos, \nEu tinha a grande saúde de não perceber coisa nenhuma, \nDe ser inteligente para entre a família, \nE de não ter as esperanças que os outros tinham por mim. \nQuando vim a ter esperanças, já não sabia ter esperanças. \nQuando vim a olhar para a vida, perdera o sentido da vida.\n\nSim, o que fui de suposto a mim mesmo,\nO que fui de coração e parentesco,\nO que fui de serões de meia-província,\nO que fui de amarem-me e eu ser menino. \nO que fui — ai, meu Deus!, o que só hoje sei que fui... \nA que distância!... \n(Nem o acho...) \nO tempo em que festejavam o dia dos meus anos!\n\nO que eu sou hoje é como a humidade no corredor do fim da casa, \nPondo grelado nas paredes...\nO que eu sou hoje (e a casa dos que me amaram treme através das minhas lágrimas), \nO que eu sou hoje é ter ...

# %%
def get_pair_frequency(tokens, counts = None): #checks for the number of token pairs in the text. Returns dictionary with pair: # of occurrences
    counts={}  if counts is None else counts
    for pair in zip(tokens, tokens[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge_pair(ids, pair, idx):
    new_ids = []
    i = 0
    while i < len(ids):
        if i< len(ids)-1 and pair[0] == ids[i] and pair[1] == ids[i+1]:
            new_ids.append(idx)
            i += 2
        else:
            new_ids.append(ids[i])
            i += 1
    return new_ids

# %%
class Tokenizer():
    def __init__(self):
        self.vocab = {idx: bytes([idx]) for idx in range(256)}
        self.merges = {}
    
    def train(self, vocab_size, text):
        tokens = text.encode('utf-8')
        for i in range(vocab_size - 256):
            pair_frequency = get_pair_frequency(tokens)
            top_pair = max(pair_frequency, key=pair_frequency.get) #returns pair that appear the most
            idx = len(self.vocab)
            print(f'Merging {top_pair} -> {idx}')
            self.merges[top_pair] = idx
            tokens = merge_pair(tokens, top_pair, idx)
            self.vocab[idx] = self.vocab[top_pair[0]] + self.vocab[top_pair[1]]
    
    def encode(self, text):
        tokens = list(text.encode('utf-8'))
        
        while len(tokens) > 1:
            pair_frequency = get_pair_frequency(tokens)
            pair = min(pair_frequency, key = lambda p:self.merges.get(p, float("inf"))) #returns pair that was merged first
            if pair not in self.merges:
                break
        
            idx = self.merges[pair] #get encoded id
            tokens = merge_pair(tokens, pair, idx)

        return tokens
    
    def decode(self, ids):
        tokens = b"".join([self.vocab[idx] for idx in ids]) #ids(list of integers as encoded) -> bytes
        text = tokens.decode("utf-8", errors='replace') #bytes -> characters
        return text

# %%
tok = Tokenizer()
tok.train(270, poems)
# Out:
# Merging (101, 32) -> 256
# Merging (111, 32) -> 257
# Merging (97, 32) -> 258
# Merging (115, 32) -> 259
# Merging (194, 160) -> 260
# Merging (260, 260) -> 261
# Merging (101, 114) -> 262
# Merging (44, 32) -> 263
# Merging (113, 117) -> 264
# Merging (109, 32) -> 265
# Merging (101, 115) -> 266
# Merging (101, 110) -> 267
# Merging (10, 10) -> 268
# Merging (111, 114) -> 269

# %%
tok.decode(tok.encode('o meu nome é Fernandão.'))
# Out:
# 'o meu nome é Fernandão.'

# %%
GPT_SPLIT_PATTERN = r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+"""

class RegexTokenizer(Tokenizer):
    def __init__(self):
        super().__init__() 
        self.pattern = GPT_SPLIT_PATTERN
        self.compiled_pattern = re.compile(self.pattern)
        self.merges = {} # (int, int) -> int
        self.vocab = {idx: bytes([idx]) for idx in range(256)} # idx -> bytes

    def train(self, text, vocab_size, verbose=False):
        
        num_merges = vocab_size - 256

        text_chunks = re.findall(self.compiled_pattern, text)        
        ids = [list(ch.encode("utf-8")) for ch in text_chunks]
        
        for i in range(num_merges):

            stats = {}

            for chunk_ids in ids:
                get_pair_frequency(chunk_ids, stats)

            top_pair = max(stats, key=stats.get) #returns most common pair
            idx = 256 + i
            
            if verbose:
                print(f'Merging {top_pair} into {idx}')
            
            ids = [merge_pair(chunk_ids, top_pair, idx) for chunk_ids in ids]
            
            self.merges[top_pair] = idx
            self.vocab[idx] = self.vocab[top_pair[0]] + self.vocab[top_pair[1]]

    def _encode_chunk(self, chunk_bytes):
        ids = list(chunk_bytes)
        while len(ids)>=2:
            stats = get_pair_frequency(ids)
            pair = min(stats, key=lambda p:self.merges.get(p, float("inf"))) #get the pair that has was merged first
            if pair not in self.merges:
                break #nothing else to merge
            
            idx = self.merges[pair]
            ids = merge_pair(ids, pair, idx)
        
        return ids

    def encode(self, text):
        # chunks encoded separately and then merged together
        text_chunks = re.findall(self.compiled_pattern, text)

        ids = []

        for chunk in text_chunks:
            chunk_bytes = chunk.encode("utf-8")
            chunk_ids = self._encode_chunk(chunk_bytes)
            ids.extend(chunk_ids)
        
        return ids

    def decode(self, ids):
        tokens = b"".join([self.vocab[idx] for idx in ids])
        text = tokens.decode("utf-8", errors='replace') #translates bytes to characters
        return text

# %%
toks = RegexTokenizer()
toks.train(poems, 5000, verbose=True)
# Out:
# Merging (32, 32) into 256
# Merging (32, 97) into 257
# Merging (32, 100) into 258
# Merging (32, 101) into 259
# Merging (32, 115) into 260
# Merging (101, 114) into 261
# Merging (32, 109) into 262
# Merging (113, 117) into 263
# Merging (32, 99) into 264
# Merging (111, 115) into 265
# Merging (32, 116) into 266
# Merging (10, 10) into 267
# Merging (111, 114) into 268
# Merging (101, 115) into 269
# Merging (32, 112) into 270
# Merging (97, 115) into 271
# Merging (32, 110) into 272
# Merging (32, 111) into 273
# Merging (110, 116) into 274
# Merging (32, 263) into 275
# Merging (97, 114) into 276
# Merging (100, 111) into 277
# Merging (275, 101) into 278
# Merging (256, 256) into 279
# Merging (195, 163) into 280
# Merging (105, 115) into 281
# Merging (280, 111) into 282
# Merging (258, 101) into 283
# Merging (105, 110) into 284
# Merging (32, 118) into 285
# Merging (101, 109) into 286
# Merging (97, 110) into 287
# Merging (32, 102) into 288
# Merging (100, 97) into 289
# Merging (46, 46) into 290
# Merging (44, 10) into 291
# Merging (111, 109) into 292
# Merging (195, 169) into 293
# Merging (114, 101) into 294
# Merging (114, 97) into 295
# Merging (101, 110) into 296
# Merging (46, 267) into 297
# Merging (101, 274) into 298
# Merging (46, 10) into 299
# Merging (97, 108) into 300
# Merging (117, 109) into 301
# Merging (101, 105) into 302
# Merging (195, 161) into 303
# Merging (32, 108) into 304
# Merging (105, 109) into 305
# Merging (259, 115) into 306
# Merging (111, 110) into 307
# Merging (32, 104) into 308
# Merging (105, 97) into 309
# Merging (97, 109) into 310
# Merging (195, 167) into 311
# Merging (100, 101) into 312
# Merging (116, 111) into 313
# Merging (114, 111) into 314
# Merging (32, 98) into 315
# Merging (262, 101) into 316
# Merging (116, 101) into 317
# Merging (32, 293) into 318
# Merging (115, 111) into 319
# Merging (32, 301) into 320
# Merging (101, 108) into 321
# Merging (272, 282) into 322
# Merging (81, 117) into 323
# Merging (195, 179) into 324
# Merging (264, 292) into 325
# Merging (116, 97) into 326
# Merging (287, 277) into 327
# Merging (258, 111) into 328
# Merging (114, 105) into 329
# Merging (117, 115) into 330
# Merging (260, 101) into 331
# Merging (104, 97) into 332
# Merging (111, 117) into 333
# Merging (105, 289) into 334
# Merging (104, 101) into 335
# Merging (32, 10) into 336
# Merging (257, 108) into 337
# Merging (272, 111) into 338
# Merging (32, 80) into 339
# Merging (279, 279) into 340
# Merging (259, 109) into 341
# Merging (258, 97) into 342
# Merging (273, 117) into 343
# Merging (117, 110) into 344
# Merging (272, 97) into 345
# Merging (32, 103) into 346
# Merging (279, 256) into 347
# Merging (347, 32) into 348
# Merging (298, 101) into 349
# Merging (32, 284) into 350
# Merging (104, 111) into 351
# Merging (257, 115) into 352
# Merging (261, 110) into 353
# Merging (105, 114) into 354
# Merging (323, 101) into 355
# Merging (105, 118) into 356
# Merging (266, 111) into 357
# Merging (276, 97) into 358
# Merging (297, 10) into 359
# Merging (115, 101) into 360
# Merging (105, 108) into 361
# Merging (105, 99) into 362
# Merging (111, 108) into 363
# Merging (195, 173) into 364
# Merging (109, 97) into 365
# Merging (296, 115) into 366
# Merging (270, 268) into 367
# Merging (32, 265) into 368
# Merging (259, 117) into 369
# Merging (32, 119) into 370
# Merging (195, 170) into 371
# Merging (109, 101) into 372
# Merging (269, 319) into 373
# Merging (260, 261) into 374
# Merging (97, 274) into 375
# Merging (103, 117) into 376
# Merging (97, 281) into 377
# Merging (258, 269) into 378
# Merging (68, 101) into 379
# Merging (373, 97) into 380
# Merging (268, 97) into 381
# Merging (264, 111) into 382
# Merging (339, 380) into 383
# Merging (70, 353) into 384
# Merging (384, 327) into 385
# Merging (226, 128) into 386
# Merging (110, 99) into 387
# Merging (32, 294) into 388
# Merging (118, 101) into 389
# Merging (105, 116) into 390
# Merging (306, 116) into 391
# Merging (266, 117) into 392
# Merging (110, 100) into 393
# Merging (32, 195) into 394
# Merging (78, 282) into 395
# Merging (32, 69) into 396
# Merging (290, 46) into 397
# Merging (105, 103) into 398
# Merging (32, 65) into 399
# Merging (260, 286) into 400
# Merging (100, 265) into 401
# Merging (32, 67) into 402
# Merging (45, 372) into 403
# Merging (263, 101) into 404
# Merging (115, 97) into 405
# Merging (99, 97) into 406
# Merging (325, 111) into 407
# Merging (99, 101) into 408
# Merging (114, 287) into 409
# Merging (264, 307) into 410
# Merging (290, 299) into 411
# Merging (386, 148) into 412
# Merging (284, 332) into 413
# Merging (266, 335) into 414
# Merging (311, 282) into 415
# Merging (270, 358) into 416
# Merging (285, 334) into 417
# Merging (320, 97) into 418
# Merging (105, 274) into 419
# Merging (284, 103) into 420
# Merging (32, 114) into 421
# Merging (32, 412) into 422
# Merging (99, 105) into 423
# Merging (298, 111) into 424
# Merging (281, 116) into 425
# Merging (262, 305) into 426
# Merging (117, 108) into 427
# Merging (316, 117) into 428
# Merging (32, 83) into 429
# Merging (32, 106) into 430
# Merging (266, 101) into 431
# Merging (108, 101) into 432
# Merging (311, 97) into 433
# Merging (266, 261) into 434
# Merging (285, 261) into 435
# Merging (260, 97) into 436
# Merging (257, 109) into 437
# Merging (262, 377) into 438
# Merging (257, 111) into 439
# Merging (97, 118) into 440
# Merging (329, 111) into 441
# Merging (266, 104) into 442
# Merging (112, 111) into 443
# Merging (32, 281) into 444
# Merging (116, 117) into 445
# Merging (100, 271) into 446
# Merging (77, 271) into 447
# Merging (105, 122) into 448
# Merging (262, 268) into 449
# Merging (343, 116) into 450
# Merging (270, 111) into 451
# Merging (105, 111) into 452
# Merging (67, 292) into 453
# Merging (97, 289) into 454
# Merging (108, 104) into 455
# Merging (392, 277) into 456
# Merging (109, 111) into 457
# Merging (264, 104) into 458
# Merging (259, 120) into 459
# Merging (260, 307) into 460
# Merging (33, 10) into 461
# Merging (32, 84) into 462
# Merging (99, 111) into 463
# Merging (344, 277) into 464
# Merging (112, 294) into 465
# Merging (337, 365) into 466
# Merging (32, 73) into 467
# Merging (108, 97) into 468
# Merging (270, 271) into 469
# Merging (260, 117) into 470
# Merging (270, 366) into 471
# Merging (293, 109) into 472
# Merging (195, 186) into 473
# Merging (382, 281) into 474
# Merging (97, 122) into 475
# Merging (394, 160) into 476
# Merging (260, 324) into 477
# Merging (262, 413) into 478
# Merging (103, 111) into 479
# Merging (273, 110) into 480
# Merging (260, 111) into 481
# Merging (387, 309) into 482
# Merging (97, 277) into 483
# Merging (272, 265) into 484
# Merging (260, 298) into 485
# Merging (257, 393) into 486
# Merging (278, 109) into 487
# Merging (258, 265) into 488
# Merging (257, 98) into 489
# Merging (311, 111) into 490
# Merging (105, 277) into 491
# Merging (32, 79) into 492
# Merging (112, 265) into 493
# Merging (114, 309) into 494
# Merging (266, 286) into 495
# Merging (114, 271) into 496
# Merging (273, 102) into 497
# Merging (32, 40) into 498
# Merging (345, 289) into 499
# Merging (270, 261) into 500
# Merging (267, 10) into 501
# Merging (97, 105) into 502
# Merging (101, 100) into 503
# Merging (117, 116) into 504
# Merging (97, 116) into 505
# Merging (308, 303) into 506
# Merging (114, 269) into 507
# Merging (118, 97) into 508
# Merging (306, 112) into 509
# Merging (274, 101) into 510
# Merging (32, 68) into 511
# Merging (83, 101) into 512
# Merging (260, 302) into 513
# Merging (117, 114) into 514
# Merging (32, 78) into 515
# Merging (321, 97) into 516
# Merging (273, 455) into 517
# Merging (98, 261) into 518
# Merging (63, 10) into 519
# Merging (332, 116) into 520
# Merging (260, 333) into 521
# Merging (264, 268) into 522
# Merging (32, 379) into 523
# Merging (257, 114) into 524
# Merging (44, 267) into 525
# Merging (334, 312) into 526
# Merging (80, 268) into 527
# Merging (115, 116) into 528
# Merging (375, 111) into 529
# Merging (32, 77) into 530
# Merging (114, 265) into 531
# Merging (262, 269) into 532
# Merging (272, 286) into 533
# Merging (258, 271) into 534
# Merging (32, 305) into 535
# Merging (98, 294) into 536
# Merging (304, 117) into 537
# Merging (275, 261) into 538
# Merging (257, 99) into 539
# Merging (268, 269) into 540
# Merging (101, 122) into 541
# Merging (260, 292) into 542
# Merging (259, 274) into 543
# Merging (105, 317) into 544
# Merging (97, 100) into 545
# Merging (266, 114) into 546
# Merging (101, 106) into 547
# Merging (97, 103) into 548
# Merging (257, 116) into 549
# Merging (270, 276) into 550
# Merging (371, 482) into 551
# Merging (356, 261) into 552
# Merging (262, 111) into 553
# Merging (101, 103) into 554
# Merging (105, 100) into 555
# Merging (308, 268) into 556
# Merging (302, 295) into 557
# Merging (302, 314) into 558
# Merging (101, 116) into 559
# Merging (288, 268) into 560
# Merging (195, 137) into 561
# Merging (290, 297) into 562
# Merging (262, 276) into 563
# Merging (276, 111) into 564
# Merging (195, 181) into 565
# Merging (101, 99) into 566
# Merging (118, 111) into 567
# Merging (340, 348) into 568
# Merging (296, 351) into 569
# Merging (480, 312) into 570
# Merging (100, 269) into 571
# Merging (262, 464) into 572
# Merging (324, 115) into 573
# Merging (117, 105) into 574
# Merging (100, 261) into 575
# Merging (32, 82) into 576
# Merging (257, 110) into 577
# Merging (306, 99) into 578
# Merging (397, 41) into 579
# Merging (269, 115) into 580
# Merging (78, 111) into 581
# Merging (264, 97) into 582
# Merging (108, 111) into 583
# Merging (118, 261) into 584
# Merging (362, 97) into 585
# Merging (98, 101) into 586
# Merging (260, 363) into 587
# Merging (310, 493) into 588
# Merging (565, 269) into 589
# Merging (118, 321) into 590
# Merging (32, 295) into 591
# Merging (281, 317) into 592
# Merging (258, 309) into 593
# Merging (315, 101) into 594
# Merging (288, 300) into 595
# Merging (453, 111) into 596
# Merging (338, 544) into 597
# Merging (103, 101) into 598
# Merging (45, 360) into 599
# Merging (381, 415) into 600
# Merging (114, 268) into 601
# Merging (270, 114) into 602
# Merging (32, 419) into 603
# Merging (257, 112) into 604
# Merging (32, 70) into 605
# Merging (259, 110) into 606
# Merging (523, 330) into 607
# Merging (115, 305) into 608
# Merging (264, 600) into 609
# Merging (105, 102) into 610
# Merging (195, 129) into 611
# Merging (104, 116) into 612
# Merging (105, 271) into 613
# Merging (109, 349) into 614
# Merging (382, 274) into 615
# Merging (474, 97) into 616
# Merging (288, 108) into 617
# Merging (68, 111) into 618
# Merging (289, 312) into 619
# Merging (106, 97) into 620
# Merging (258, 268) into 621
# Merging (419, 111) into 622
# Merging (310, 349) into 623
# Merging (430, 303) into 624
# Merging (117, 277) into 625
# Merging (498, 579) into 626
# Merging (398, 111) into 627
# Merging (357, 401) into 628
# Merging (400, 465) into 629
# Merging (344, 406) into 630
# Merging (296, 277) into 631
# Merging (101, 117) into 632
# Merging (108, 118) into 633
# Merging (98, 295) into 634
# Merging (260, 282) into 635
# Merging (33, 267) into 636
# Merging (69, 115) into 637
# Merging (257, 263) into 638
# Merging (32, 344) into 639
# Merging (99, 261) into 640
# Merging (32, 303) into 641
# Merging (263, 261) into 642
# Merging (111, 274) into 643
# Merging (367, 404) into 644
# Merging (422, 10) into 645
# Merging (288, 475) into 646
# Merging (116, 104) into 647
# Merging (269, 116) into 648
# Merging (474, 271) into 649
# Merging (547, 111) into 650
# Merging (80, 358) into 651
# Merging (286, 265) into 652
# Merging (32, 86) into 653
# Merging (110, 111) into 654
# Merging (323, 327) into 655
# Merging (633, 564) into 656
# Merging (402, 588) into 657
# Merging (104, 271) into 658
# Merging (270, 314) into 659
# Merging (266, 520) into 660
# Merging (69, 109) into 661
# Merging (262, 271) into 662
# Merging (304, 101) into 663
# Merging (611, 656) into 664
# Merging (301, 97) into 665
# Merging (115, 423) into 666
# Merging (304, 307) into 667
# Merging (532, 457) into 668
# Merging (122, 97) into 669
# Merging (362, 276) into 670
# Merging (45, 317) into 671
# Merging (195, 162) into 672
# Merging (287, 433) into 673
# Merging (69, 117) into 674
# Merging (469, 405) into 675
# Merging (262, 425) into 676
# Merging (288, 111) into 677
# Merging (346, 409) into 678
# Merging (285, 541) into 679
# Merging (274, 269) into 680
# Merging (259, 114) into 681
# Merging (264, 293) into 682
# Merging (258, 448) into 683
# Merging (59, 10) into 684
# Merging (104, 265) into 685
# Merging (105, 120) into 686
# Merging (112, 261) into 687
# Merging (310, 424) into 688
# Merging (376, 472) into 689
# Merging (313, 117) into 690
# Merging (285, 356) into 691
# Merging (65, 115) into 692
# Merging (117, 295) into 693
# Merging (304, 111) into 694
# Merging (116, 271) into 695
# Merging (302, 111) into 696
# Merging (97, 99) into 697
# Merging (556, 601) into 698
# Merging (84, 111) into 699
# Merging (388, 300) into 700
# Merging (576, 101) into 701
# Merging (85, 109) into 702
# Merging (258, 281) into 703
# Merging (264, 287) into 704
# Merging (275, 300) into 705
# Merging (321, 111) into 706
# Merging (116, 265) into 707
# Merging (259, 387) into 708
# Merging (391, 303) into 709
# Merging (517, 265) into 710
# Merging (262, 287) into 711
# Merging (109, 265) into 712
# Merging (302, 97) into 713
# Merging (310, 265) into 714
# Merging (105, 313) into 715
# Merging (105, 326) into 716
# Merging (431, 117) into 717
# Merging (293, 441) into 718
# Merging (264, 300) into 719
# Merging (78, 286) into 720
# Merging (272, 630) into 721
# Merging (115, 265) into 722
# Merging (275, 327) into 723
# Merging (105, 295) into 724
# Merging (262, 121) into 725
# Merging (437, 268) into 726
# Merging (261, 101) into 727
# Merging (444, 313) into 728
# Merging (32, 45) into 729
# Merging (262, 296) into 730
# Merging (262, 300) into 731
# Merging (270, 265) into 732
# Merging (78, 97) into 733
# Merging (306, 326) into 734
# Merging (272, 573) into 735
# Merging (101, 276) into 736
# Merging (308, 440) into 737
# Merging (32, 355) into 738
# Merging (340, 340) into 739
# Merging (284, 351) into 740
# Merging (32, 76) into 741
# Merging (270, 296) into 742
# Merging (350, 102) into 743
# Merging (284, 289) into 744
# Merging (362, 111) into 745
# Merging (266, 569) into 746
# Merging (32, 72) into 747
# Merging (32, 314) into 748
# Merging (264, 271) into 749
# Merging (65, 104) into 750
# Merging (331, 117) into 751
# Merging (39, 115) into 752
# Merging (103, 276) into 753
# Merging (460, 351) into 754
# Merging (32, 329) into 755
# Merging (421, 117) into 756
# Merging (111, 122) into 757
# Merging (114, 117) into 758
# Merging (272, 271) into 759
# Merging (449, 317) into 760
# Merging (103, 97) into 761
# Merging (481, 536) into 762
# Merging (266, 295) into 763
# Merging (670, 277) into 764
# Merging (701, 281) into 765
# Merging (73, 73) into 766
# Merging (82, 764) into 767
# Merging (105, 265) into 768
# Merging (471, 276) into 769
# Merging (58, 10) into 770
# Merging (266, 105) into 771
# Merging (537, 122) into 772
# Merging (264, 276) into 773
# Merging (304, 105) into 774
# Merging (32, 390) into 775
# Merging (311, 589) into 776
# Merging (114, 261) into 777
# Merging (444, 319) into 778
# Merging (63, 267) into 779
# Merging (315, 286) into 780
# Merging (283, 330) into 781
# Merging (352, 608) into 782
# Merging (485, 354) into 783
# Merging (390, 104) into 784
# Merging (265, 360) into 785
# Merging (259, 295) into 786
# Merging (323, 286) into 787
# Merging (284, 111) into 788
# Merging (264, 310) into 789
# Merging (270, 294) into 790
# Merging (285, 105) into 791
# Merging (304, 303) into 792
# Merging (315, 114) into 793
# Merging (308, 111) into 794
# Merging (306, 404) into 795
# Merging (284, 97) into 796
# Merging (543, 294) into 797
# Merging (471, 688) into 798
# Merging (104, 276) into 799
# Merging (32, 66) into 800
# Merging (316, 330) into 801
# Merging (268, 110) into 802
# Merging (32, 354) into 803
# Merging (285, 281) into 804
# Merging (357, 289) into 805
# Merging (266, 282) into 806
# Merging (283, 686) into 807
# Merging (303, 115) into 808
# Merging (270, 295) into 809
# Merging (260, 622) into 810
# Merging (83, 286) into 811
# Merging (527, 404) into 812
# Merging (546, 592) into 813
# Merging (509, 261) into 814
# Merging (116, 353) into 815
# Merging (106, 101) into 816
# Merging (682, 117) into 817
# Merging (445, 295) into 818
# Merging (32, 91) into 819
# Merging (116, 261) into 820
# Merging (68, 97) into 821
# Merging (450, 314) into 822
# Merging (259, 432) into 823
# Merging (308, 301) into 824
# Merging (552, 319) into 825
# Merging (103, 612) into 826
# Merging (269, 360) into 827
# Merging (65, 108) into 828
# Merging (107, 101) into 829
# Merging (305, 97) into 830
# Merging (98, 111) into 831
# Merging (469, 115) into 832
# Merging (284, 277) into 833
# Merging (676, 718) into 834
# Merging (296, 104) into 835
# Merging (195, 180) into 836
# Merging (114, 286) into 837
# Merging (32, 268) into 838
# Merging (517, 276) into 839
# Merging (677, 105) into 840
# Merging (84, 625) into 841
# Merging (459, 425) into 842
# Merging (114, 276) into 843
# Merging (357, 446) into 844
# Merging (260, 268) into 845
# Merging (269, 317) into 846
# Merging (296, 100) into 847
# Merging (364, 590) into 848
# Merging (333, 463) into 849
# Merging (678, 312) into 850
# Merging (194, 171) into 851
# Merging (83, 324) into 852
# Merging (257, 103) into 853
# Merging (79, 115) into 854
# Merging (262, 280) into 855
# Merging (283, 274) into 856
# Merging (305, 424) into 857
# Merging (108, 269) into 858
# Merging (338, 116) into 859
# Merging (264, 261) into 860
# Merging (298, 265) into 861
# Merging (410, 666) into 862
# Merging (434, 295) into 863
# Merging (824, 287) into 864
# Merging (856, 314) into 865
# Merging (287, 100) into 866
# Merging (522, 443) into 867
# Merging (77, 632) into 868
# Merging (376, 101) into 869
# Merging (261, 111) into 870
# Merging (450, 531) into 871
# Merging (308, 292) into 872
# Merging (290, 359) into 873
# Merging (302, 313) into 874
# Merging (288, 97) into 875
# Merging (324, 112) into 876
# Merging (32, 395) into 877
# Merging (85, 365) into 878
# Merging (450, 295) into 879
# Merging (112, 268) into 880
# Merging (264, 108) into 881
# Merging (470, 97) into 882
# Merging (346, 349) into 883
# Merging (116, 276) into 884
# Merging (705, 642) into 885
# Merging (315, 111) into 886
# Merging (65, 393) into 887
# Merging (286, 98) into 888
# Merging (436, 518) into 889
# Merging (617, 540) into 890
# Merging (288, 305) into 891
# Merging (737, 261) into 892
# Merging (311, 271) into 893
# Merging (99, 104) into 894
# Merging (262, 97) into 895
# Merging (195, 147) into 896
# Merging (781, 269) into 897
# Merging (495, 443) into 898
# Merging (337, 554) into 899
# Merging (638, 105) into 900
# Merging (110, 312) into 901
# Merging (343, 118) into 902
# Merging (114, 292) into 903
# Merging (264, 329) into 904
# Merging (308, 381) into 905
# Merging (108, 271) into 906
# Merging (257, 102) into 907
# Merging (114, 305) into 908
# Merging (443, 281) into 909
# Merging (306, 690) into 910
# Merging (112, 97) into 911
# Merging (264, 375) into 912
# Merging (357, 277) into 913
# Merging (391, 276) into 914
# Merging (99, 307) into 915
# Merging (288, 381) into 916
# Merging (442, 333) into 917
# Merging (435, 619) into 918
# Merging (285, 424) into 919
# Merging (101, 408) into 920
# Merging (266, 409) into 921
# Merging (33, 501) into 922
# Merging (261, 97) into 923
# Merging (295, 289) into 924
# Merging (259, 468) into 925
# Merging (370, 784) into 926
# Merging (262, 292) into 927
# Merging (361, 108) into 928
# Merging (284, 689) into 929
# Merging (262, 284) into 930
# Merging (262, 117) into 931
# Merging (285, 363) into 932
# Merging (194, 187) into 933
# Merging (104, 280) into 934
# Merging (108, 100) into 935
# Merging (667, 598) into 936
# Merging (72, 303) into 937
# Merging (410, 335) into 938
# Merging (32, 324) into 939
# Merging (32, 87) into 940
# Merging (293, 115) into 941
# Merging (538, 111) into 942
# Merging (549, 293) into 943
# Merging (285, 321) into 944
# Merging (366, 97) into 945
# Merging (108, 121) into 946
# Merging (402, 292) into 947
# Merging (79, 117) into 948
# Merging (339, 268) into 949
# Merging (308, 97) into 950
# Merging (257, 744) into 951
# Merging (310, 98) into 952
# Merging (270, 97) into 953
# Merging (331, 620) into 954
# Merging (437, 276) into 955
# Merging (370, 104) into 956
# Merging (288, 321) into 957
# Merging (259, 815) into 958
# Merging (324, 494) into 959
# Merging (281, 111) into 960
# Merging (120, 111) into 961
# Merging (300, 389) into 962
# Merging (672, 482) into 963
# Merging (100, 309) into 964
# Merging (260, 116) into 965
# Merging (270, 507) into 966
# Merging (325, 112) into 967
# Merging (641, 376) into 968
# Merging (281, 457) into 969
# Merging (371, 387) into 970
# Merging (451, 575) into 971
# Merging (101, 104) into 972
# Merging (679, 269) into 973
# Merging (458, 268) into 974
# Merging (392, 97) into 975
# Merging (99, 117) into 976
# Merging (32, 121) into 977
# Merging (550, 116) into 978
# Merging (99, 276) into 979
# Merging (270, 101) into 980
# Merging (542, 634) into 981
# Merging (106, 111) into 982
# Merging (962, 122) into 983
# Merging (114, 118) into 984
# Merging (398, 612) into 985
# Merging (275, 529) into 986
# Merging (346, 117) into 987
# Merging (270, 849) into 988
# Merging (264, 335) into 989
# Merging (109, 271) into 990
# Merging (730, 265) into 991
# Merging (84, 335) into 992
# Merging (257, 274) into 993
# Merging (257, 265) into 994
# Merging (99, 427) into 995
# Merging (602, 876) into 996
# Merging (285, 650) into 997
# Merging (103, 286) into 998
# Merging (421, 269) into 999
# Merging (270, 300) into 1000
# Merging (260, 296) into 1001
# Merging (436, 586) into 1002
# Merging (112, 276) into 1003
# Merging (321, 101) into 1004
# Merging (45, 972) into 1005
# Merging (285, 371) into 1006
# Merging (364, 110) into 1007
# Merging (45, 108) into 1008
# Merging (288, 117) into 1009
# Merging (952, 472) into 1010
# Merging (32, 71) into 1011
# Merging (708, 643) into 1012
# Merging (621, 109) into 1013
# Merging (84, 569) into 1014
# Merging (402, 97) into 1015
# Merging (330, 116) into 1016
# Merging (276, 309) into 1017
# Merging (683, 261) into 1018
# Merging (32, 555) into 1019
# Merging (356, 101) into 1020
# Merging (270, 516) into 1021
# Merging (288, 574) into 1022
# Merging (288, 464) into 1023
# Merging (460, 111) into 1024
# Merging (305, 111) into 1025
# Merging (260, 361) into 1026
# Merging (264, 454) into 1027
# Merging (518, 313) into 1028
# Merging (794, 816) into 1029
# Merging (117, 118) into 1030
# Merging (69, 274) into 1031
# Merging (855, 265) into 1032
# Merging (445, 294) into 1033
# Merging (268, 372) into 1034
# Merging (288, 441) into 1035
# Merging (470, 98) into 1036
# Merging (45, 111) into 1037
# Merging (105, 294) into 1038
# Merging (195, 128) into 1039
# Merging (337, 108) into 1040
# Merging (288, 101) into 1041
# Merging (574, 313) into 1042
# Merging (83, 111) into 1043
# Merging (302, 120) into 1044
# Merging (63, 501) into 1045
# Merging (79, 901) into 1046
# Merging (100, 452) into 1047
# Merging (32, 851) into 1048
# Merging (288, 361) into 1049
# Merging (694, 389) into 1050
# Merging (285, 286) into 1051
# Merging (262, 303) into 1052
# Merging (306, 317) into 1053
# Merging (391, 924) into 1054
# Merging (927, 424) into 1055
# Merging (105, 268) into 1056
# Merging (65, 111) into 1057
# Merging (105, 376) into 1058
# Merging (258, 276) into 1059
# Merging (337, 472) into 1060
# Merging (264, 363) into 1061
# Merging (285, 552) into 1062
# Merging (394, 186) into 1063
# Merging (436, 98) into 1064
# Merging (364, 115) into 1065
# Merging (262, 282) into 1066
# Merging (538, 261) into 1067
# Merging (603, 261) into 1068
# Merging (274, 111) into 1069
# Merging (321, 271) into 1070
# Merging (272, 554) into 1071
# Merging (862, 551) into 1072
# Merging (285, 97) into 1073
# Merging (73, 110) into 1074
# Merging (268, 101) into 1075
# Merging (260, 105) into 1076
# Merging (116, 361) into 1077
# Merging (41, 10) into 1078
# Merging (281, 313) into 1079
# Merging (100, 105) into 1080
# Merging (375, 101) into 1081
# Merging (323, 870) into 1082
# Merging (285, 300) into 1083
# Merging (45, 468) into 1084
# Merging (641, 984) into 1085
# Merging (68, 269) into 1086
# Merging (476, 115) into 1087
# Merging (375, 97) into 1088
# Merging (80, 111) into 1089
# Merging (101, 112) into 1090
# Merging (260, 305) into 1091
# Merging (298, 269) into 1092
# Merging (308, 261) into 1093
# Merging (271, 317) into 1094
# Merging (388, 112) into 1095
# Merging (271, 116) into 1096
# Merging (285, 757) into 1097
# Merging (371, 109) into 1098
# Merging (1015, 558) into 1099
# Merging (515, 111) into 1100
# Merging (84, 79) into 1101
# Merging (45, 312) into 1102
# Merging (110, 265) into 1103
# Merging (260, 945) into 1104
# Merging (399, 393) into 1105
# Merging (32, 361) into 1106
# Merging (83, 261) into 1107
# Merging (663, 118) into 1108
# Merging (304, 97) into 1109
# Merging (410, 102) into 1110
# Merging (515, 97) into 1111
# Merging (337, 313) into 1112
# Merging (430, 111) into 1113
# Merging (276, 100) into 1114
# Merging (288, 903) into 1115
# Merging (378, 116) into 1116
# Merging (330, 97) into 1117
# Merging (281, 97) into 1118
# Merging (32, 107) into 1119
# Merging (639, 825) into 1120
# Merging (406, 98) into 1121
# Merging (458, 310) into 1122
# Merging (398, 110) into 1123
# Merging (45, 583) into 1124
# Merging (421, 265) into 1125
# Merging (65, 263) into 1126
# Merging (398, 97) into 1127
# Merging (104, 302) into 1128
# Merging (105, 307) into 1129
# Merging (272, 929) into 1130
# Merging (329, 271) into 1131
# Merging (296, 271) into 1132
# Merging (749, 97) into 1133
# Merging (105, 98) into 1134
# Merging (266, 268) into 1135
# Merging (266, 1010) into 1136
# Merging (329, 265) into 1137
# Merging (32, 267) into 1138
# Merging (430, 287) into 1139
# Merging (262, 1042) into 1140
# Merging (115, 271) into 1141
# Merging (272, 301) into 1142
# Merging (484, 405) into 1143
# Merging (921, 115) into 1144
# Merging (423, 277) into 1145
# Merging (65, 116) into 1146
# Merging (104, 261) into 1147
# Merging (704, 405) into 1148
# Merging (350, 473) into 1149
# Merging (32, 441) into 1150
# Merging (117, 112) into 1151
# Merging (271, 326) into 1152
# Merging (99, 268) into 1153
# Merging (32, 447) into 1154
# Merging (45, 97) into 1155
# Merging (99, 265) into 1156
# Merging (828, 1028) into 1157
# Merging (111, 100) into 1158
# Merging (968, 97) into 1159
# Merging (83, 305) into 1160
# Merging (311, 265) into 1161
# Merging (272, 101) into 1162
# Merging (436, 117) into 1163
# Merging (83, 333) into 1164
# Merging (917, 826) into 1165
# Merging (318, 115) into 1166
# Merging (99, 271) into 1167
# Merging (591, 122) into 1168
# Merging (74, 303) into 1169
# Merging (396, 115) into 1170
# Merging (112, 101) into 1171
# Merging (118, 265) into 1172
# Merging (899, 494) into 1173
# Merging (610, 261) into 1174
# Merging (77, 377) into 1175
# Merging (285, 265) into 1176
# Merging (269, 326) into 1177
# Merging (337, 105) into 1178
# Merging (270, 503) into 1179
# Merging (110, 101) into 1180
# Merging (308, 333) into 1181
# Merging (667, 103) into 1182
# Merging (742, 319) into 1183
# Merging (325, 465) into 1184
# Merging (308, 101) into 1185
# Merging (316, 455) into 1186
# Merging (485, 491) into 1187
# Merging (578, 294) into 1188
# Merging (304, 483) into 1189
# Merging (304, 356) into 1190
# Merging (258, 613) into 1191
# Merging (285, 282) into 1192
# Merging (410, 115) into 1193
# Merging (110, 115) into 1194
# Merging (532, 365) into 1195
# Merging (102, 284) into 1196
# Merging (285, 548) into 1197
# Merging (442, 281) into 1198
# Merging (117, 97) into 1199
# Merging (112, 108) into 1200
# Merging (337, 689) into 1201
# Merging (260, 104) into 1202
# Merging (370, 268) into 1203
# Merging (314, 117) into 1204
# Merging (451, 312) into 1205
# Merging (304, 888) into 1206
# Merging (273, 98) into 1207
# Merging (108, 351) into 1208
# Merging (435, 722) into 1209
# Merging (626, 10) into 1210
# Merging (292, 101) into 1211
# Merging (32, 85) into 1212
# Merging (105, 401) into 1213
# Merging (473, 115) into 1214
# Merging (257, 294) into 1215
# Merging (375, 271) into 1216
# Merging (957, 448) into 1217
# Merging (270, 706) into 1218
# Merging (257, 122) into 1219
# Merging (345, 118) into 1220
# Merging (345, 818) into 1221
# Merging (330, 282) into 1222
# Merging (272, 835) into 1223
# Merging (306, 360) into 1224
# Merging (285, 309) into 1225
# Merging (77, 101) into 1226
# Merging (535, 548) into 1227
# Merging (303, 441) into 1228
# Merging (904, 673) into 1229
# Merging (78, 454) into 1230
# Merging (88, 88) into 1231
# Merging (315, 276) into 1232
# Merging (323, 300) into 1233
# Merging (68, 1044) into 1234
# Merging (287, 934) into 1235
# Merging (429, 101) into 1236
# Merging (270, 117) into 1237
# Merging (118, 271) into 1238
# Merging (481, 102) into 1239
# Merging (364, 423) into 1240
# Merging (80, 271) into 1241
# Merging (266, 802) into 1242
# Merging (361, 111) into 1243
# Merging (84, 104) into 1244
# Merging (610, 101) into 1245
# Merging (105, 312) into 1246
# Merging (288, 785) into 1247
# Merging (842, 354) into 1248
# Merging (324, 105) into 1249
# Merging (97, 312) into 1250
# Merging (283, 909) into 1251
# Merging (1168, 282) into 1252
# Merging (266, 276) into 1253
# Merging (732, 319) into 1254
# Merging (1139, 516) into 1255
# Merging (257, 1121) into 1256
# Merging (265, 116) into 1257
# Merging (270, 269) into 1258
# Merging (308, 281) into 1259
# Merging (264, 514) into 1260
# Merging (271, 101) into 1261
# Merging (285, 502) into 1262
# Merging (659, 102) into 1263
# Merging (105, 101) into 1264
# Merging (654, 119) into 1265
# Merging (467, 110) into 1266
# Merging (397, 93) into 1267
# Merging (420, 115) into 1268
# Merging (303, 590) into 1269
# Merging (970, 452) into 1270
# Merging (97, 490) into 1271
# Merging (108, 332) into 1272
# Merging (1085, 540) into 1273
# Merging (65, 83) into 1274
# Merging (304, 333) into 1275
# Merging (325, 627) into 1276
# Merging (315, 504) into 1277
# Merging (265, 111) into 1278
# Merging (449, 777) into 1279
# Merging (370, 101) into 1280
# Merging (1186, 268) into 1281
# Merging (109, 98) into 1282
# Merging (77, 413) into 1283
# Merging (264, 117) into 1284
# Merging (65, 85) into 1285
# Merging (275, 281) into 1286
# Merging (65, 78) into 1287
# Merging (100, 268) into 1288
# Merging (103, 294) into 1289
# Merging (108, 117) into 1290
# Merging (324, 110) into 1291
# Merging (391, 409) into 1292
# Merging (69, 528) into 1293
# Merging (647, 261) into 1294
# Merging (356, 97) into 1295
# Merging (260, 785) into 1296
# Merging (103, 454) into 1297
# Merging (535, 880) into 1298
# Merging (112, 507) into 1299
# Merging (394, 137) into 1300
# Merging (578, 117) into 1301
# Merging (304, 335) into 1302
# Merging (350, 115) into 1303
# Merging (118, 269) into 1304
# Merging (260, 287) into 1305
# Merging (257, 680) into 1306
# Merging (756, 97) into 1307
# Merging (700, 526) into 1308
# Merging (947, 111) into 1309
# Merging (260, 300) into 1310
# Merging (284, 100) into 1311
# Merging (264, 294) into 1312
# Merging (263, 296) into 1313
# Merging (537, 276) into 1314
# Merging (378, 99) into 1315
# Merging (500, 102) into 1316
# Merging (832, 276) into 1317
# Merging (329, 313) into 1318
# Merging (307, 101) into 1319
# Merging (32, 330) into 1320
# Merging (541, 97) into 1321
# Merging (550, 317) into 1322
# Merging (65, 82) into 1323
# Merging (315, 409) into 1324
# Merging (1031, 294) into 1325
# Merging (442, 121) into 1326
# Merging (270, 108) into 1327
# Merging (1219, 427) into 1328
# Merging (435, 289) into 1329
# Merging (853, 381) into 1330
# Merging (370, 271) into 1331
# Merging (315, 294) into 1332
# Merging (399, 115) into 1333
# Merging (458, 282) into 1334
# Merging (460, 685) into 1335
# Merging (500, 100) into 1336
# Merging (678, 571) into 1337
# Merging (445, 114) into 1338
# Merging (391, 294) into 1339
# Merging (110, 580) into 1340
# Merging (370, 520) into 1341
# Merging (537, 753) into 1342
# Merging (100, 276) into 1343
# Merging (288, 566) into 1344
# Merging (262, 286) into 1345
# Merging (643, 1250) into 1346
# Merging (257, 365) into 1347
# Merging (356, 111) into 1348
# Merging (266, 983) into 1349
# Merging (45, 1103) into 1350
# Merging (1026, 1270) into 1351
# Merging (333, 935) into 1352
# Merging (692, 608) into 1353
# Merging (287, 893) into 1354
# Merging (350, 99) into 1355
# Merging (288, 363) into 1356
# Merging (98, 496) into 1357
# Merging (1149, 1077) into 1358
# Merging (266, 1098) into 1359
# Merging (284, 300) into 1360
# Merging (399, 104) into 1361
# Merging (364, 277) into 1362
# Merging (295, 99) into 1363
# Merging (308, 866) into 1364
# Merging (872, 366) into 1365
# Merging (261, 295) into 1366
# Merging (306, 405) into 1367
# Merging (421, 286) into 1368
# Merging (288, 276) into 1369
# Merging (459, 592) into 1370
# Merging (302, 271) into 1371
# Merging (78, 265) into 1372
# Merging (316, 277) into 1373
# Merging (582, 586) into 1374
# Merging (116, 300) into 1375
# Merging (286, 349) into 1376
# Merging (440, 300) into 1377
# Merging (604, 1132) into 1378
# Merging (1221, 108) into 1379
# Merging (260, 349) into 1380
# Merging (32, 1123) into 1381
# Merging (484, 319) into 1382
# Merging (285, 354) into 1383
# Merging (32, 74) into 1384
# Merging (1033, 669) into 1385
# Merging (775, 115) into 1386
# Merging (298, 97) into 1387
# Merging (1013, 354) into 1388
# Merging (509, 1271) into 1389
# Merging (257, 100) into 1390
# Merging (872, 286) into 1391
# Merging (378, 547) into 1392
# Merging (462, 335) into 1393
# Merging (258, 425) into 1394
# Merging (502, 961) into 1395
# Merging (80, 261) into 1396
# Merging (814, 673) into 1397
# Merging (285, 1346) into 1398
# Merging (97, 121) into 1399
# Merging (521, 108) into 1400
# Merging (386, 166) into 1401
# Merging (270, 293) into 1402
# Merging (262, 545) into 1403
# Merging (275, 371) into 1404
# Merging (338, 567) into 1405
# Merging (489, 969) into 1406
# Merging (1119, 1265) into 1407
# Merging (396, 117) into 1408
# Merging (67, 307) into 1409
# Merging (259, 858) into 1410
# Merging (304, 1245) into 1411
# Merging (350, 640) into 1412
# Merging (742, 97) into 1413
# Merging (302, 326) into 1414
# Merging (116, 296) into 1415
# Merging (270, 303) into 1416
# Merging (117, 271) into 1417
# Merging (386, 153) into 1418
# Merging (390, 276) into 1419
# Merging (116, 269) into 1420
# Merging (481, 98) into 1421
# Merging (793, 284) into 1422
# Merging (449, 101) into 1423
# Merging (462, 104) into 1424
# Merging (363, 111) into 1425
# Merging (980, 1313) into 1426
# Merging (458, 117) into 1427
# Merging (304, 276) into 1428
# Merging (266, 529) into 1429
# Merging (293, 1047) into 1430
# Merging (378, 650) into 1431
# Merging (743, 284) into 1432
# Merging (258, 294) into 1433
# Merging (295, 118) into 1434
# Merging (264, 588) into 1435
# Merging (346, 108) into 1436
# Merging (449, 313) into 1437
# Merging (930, 658) into 1438
# Merging (268, 277) into 1439
# Merging (1427, 508) into 1440
# Merging (97, 317) into 1441
# Merging (99, 309) into 1442
# Merging (1073, 479) into 1443
# Merging (1019, 713) into 1444
# Merging (72, 79) into 1445
# Merging (996, 441) into 1446
# Merging (308, 736) into 1447
# Merging (774, 829) into 1448
# Merging (258, 356) into 1449
# Merging (675, 277) into 1450
# Merging (334, 571) into 1451
# Merging (296, 433) into 1452
# Merging (262, 505) into 1453
# Merging (69, 83) into 1454
# Merging (332, 277) into 1455
# Merging (69, 78) into 1456
# Merging (105, 314) into 1457
# Merging (1116, 788) into 1458
# Merging (341, 98) into 1459
# Merging (763, 122) into 1460
# Merging (315, 295) into 1461
# Merging (350, 915) into 1462
# Merging (97, 98) into 1463
# Merging (556, 271) into 1464
# Merging (1008, 335) into 1465
# Merging (364, 116) into 1466
# Merging (860, 313) into 1467
# Merging (315, 121) into 1468
# Merging (343, 114) into 1469
# Merging (321, 265) into 1470
# Merging (460, 799) into 1471
# Merging (1329, 100) into 1472
# Merging (288, 294) into 1473
# Merging (528, 1363) into 1474
# Merging (719, 365) into 1475
# Merging (306, 115) into 1476
# Merging (394, 162) into 1477
# Merging (646, 261) into 1478
# Merging (306, 102) into 1479
# Merging (1305, 869) into 1480
# Merging (346, 757) into 1481
# Merging (542, 265) into 1482
# Merging (329, 114) into 1483
# Merging (1001, 282) into 1484
# Merging (440, 97) into 1485
# Merging (103, 295) into 1486
# Merging (617, 268) into 1487
# Merging (300, 108) into 1488
# Merging (307, 111) into 1489
# Merging (553, 277) into 1490
# Merging (389, 281) into 1491
# Merging (105, 117) into 1492
# Merging (1007, 263) into 1493
# Merging (1000, 440) into 1494
# Merging (73, 115) into 1495
# Merging (325, 101) into 1496
# Merging (271, 360) into 1497
# Merging (602, 305) into 1498
# Merging (72, 111) into 1499
# Merging (70, 475) into 1500
# Merging (350, 312) into 1501
# Merging (1253, 312) into 1502
# Merging (258, 303) into 1503
# Merging (65, 76) into 1504
# Merging (371, 115) into 1505
# Merging (375, 265) into 1506
# Merging (302, 531) into 1507
# Merging (766, 73) into 1508
# Merging (342, 121) into 1509
# Merging (337, 103) into 1510
# Merging (79, 504) into 1511
# Merging (363, 97) into 1512
# Merging (257, 118) into 1513
# Merging (699, 401) into 1514
# Merging (285, 303) into 1515
# Merging (32, 1058) into 1516
# Merging (269, 313) into 1517
# Merging (489, 115) into 1518
# Merging (489, 1474) into 1519
# Merging (432, 120) into 1520
# Merging (419, 97) into 1521
# Merging (264, 529) into 1522
# Merging (119, 110) into 1523
# Merging (328, 647) into 1524
# Merging (950, 389) into 1525
# Merging (315, 330) into 1526
# Merging (262, 502) into 1527
# Merging (287, 111) into 1528
# Merging (258, 1174) into 1529
# Merging (1374, 433) into 1530
# Merging (346, 295) into 1531
# Merging (83, 282) into 1532
# Merging (262, 1214) into 1533
# Merging (281, 115) into 1534
# Merging (110, 97) into 1535
# Merging (1182, 1493) into 1536
# Merging (845, 114) into 1537
# Merging (367, 326) into 1538
# Merging (325, 831) into 1539
# Merging (793, 1118) into 1540
# Merging (99, 116) into 1541
# Merging (886, 406) into 1542
# Merging (84, 69) into 1543
# Merging (264, 265) into 1544
# Merging (264, 101) into 1545
# Merging (266, 294) into 1546
# Merging (338, 119) into 1547
# Merging (83, 1101) into 1548
# Merging (560, 365) into 1549
# Merging (388, 108) into 1550
# Merging (390, 265) into 1551
# Merging (296, 575) into 1552
# Merging (445, 314) into 1553
# Merging (344, 289) into 1554
# Merging (353, 111) into 1555
# Merging (99, 693) into 1556
# Merging (261, 310) into 1557
# Merging (789, 443) into 1558
# Merging (111, 107) into 1559
# Merging (1212, 110) into 1560
# Merging (117, 98) into 1561
# Merging (272, 1030) into 1562
# Merging (285, 475) into 1563
# Merging (264, 830) into 1564
# Merging (470, 112) into 1565
# Merging (296, 332) into 1566
# Merging (485, 857) into 1567
# Merging (1083, 101) into 1568
# Merging (106, 566) into 1569
# Merging (350, 118) into 1570
# Merging (262, 427) into 1571
# Merging (116, 115) into 1572
# Merging (285, 280) into 1573
# Merging (431, 330) into 1574
# Merging (84, 117) into 1575
# Merging (266, 413) into 1576
# Merging (1223, 665) into 1577
# Merging (790, 99) into 1578
# Merging (288, 585) into 1579
# Merging (437, 111) into 1580
# Merging (108, 116) into 1581
# Merging (300, 365) into 1582
# Merging (462, 111) into 1583
# Merging (284, 115) into 1584
# Merging (697, 104) into 1585
# Merging (302, 496) into 1586
# Merging (1052, 479) into 1587
# Merging (65, 109) into 1588
# Merging (511, 69) into 1589
# Merging (813, 669) into 1590
# Merging (711, 934) into 1591
# Merging (553, 118) into 1592
# Merging (295, 277) into 1593
# Merging (606, 103) into 1594
# Merging (86, 286) into 1595
# Merging (79, 82) into 1596
# Merging (370, 928) into 1597
# Merging (819, 1267) into 1598
# Merging (505, 104) into 1599
# Merging (1285, 1548) into 1600
# Merging (315, 321) into 1601
# Merging (268, 111) into 1602
# Merging (315, 292) into 1603
# Merging (1296, 479) into 1604
# Merging (346, 111) into 1605
# Merging (265, 97) into 1606
# Merging (637, 690) into 1607
# Merging (276, 310) into 1608
# Merging (743, 963) into 1609
# Merging (266, 300) into 1610
# Merging (78, 630) into 1611
# Merging (604, 276) into 1612
# Merging (1433, 310) into 1613
# Merging (331, 101) into 1614
# Merging (275, 1261) into 1615
# Merging (79, 78) into 1616
# Merging (437, 1235) into 1617
# Merging (1298, 326) into 1618
# Merging (63, 93) into 1619
# Merging (977, 333) into 1620
# Merging (995, 111) into 1621
# Merging (1560, 825) into 1622
# Merging (1104, 776) into 1623
# Merging (379, 909) into 1624
# Merging (1111, 1385) into 1625
# Merging (296, 312) into 1626
# Merging (1001, 360) into 1627
# Merging (78, 271) into 1628
# Merging (350, 289) into 1629
# Merging (451, 536) into 1630
# Merging (1009, 1553) into 1631
# Merging (288, 293) into 1632
# Merging (295, 109) into 1633
# Merging (331, 330) into 1634
# Merging (99, 294) into 1635
# Merging (105, 112) into 1636
# Merging (288, 448) into 1637
# Merging (804, 326) into 1638
# Merging (45, 324) into 1639
# Merging (398, 271) into 1640
# Merging (117, 300) into 1641
# Merging (473, 98) into 1642
# Merging (264, 758) into 1643
# Merging (1533, 585) into 1644
# Merging (1125, 271) into 1645
# Merging (732, 115) into 1646
# Merging (350, 100) into 1647
# Merging (555, 282) into 1648
# Merging (902, 354) into 1649
# Merging (606, 102) into 1650
# Merging (410, 408) into 1651
# Merging (1095, 349) into 1652
# Merging (1063, 110) into 1653
# Merging (394, 147) into 1654
# Merging (469, 319) into 1655
# Merging (87, 104) into 1656
# Merging (663, 389) into 1657
# Merging (548, 286) into 1658
# Merging (330, 101) into 1659
# Merging (285, 333) into 1660
# Merging (691, 111) into 1661
# Merging (272, 665) into 1662
# Merging (268, 317) into 1663
# Merging (195, 131) into 1664
# Merging (691, 101) into 1665
# Merging (32, 323) into 1666
# Merging (83, 97) into 1667
# Merging (583, 119) into 1668
# Merging (595, 326) into 1669
# Merging (288, 541) into 1670
# Merging (1106, 1222) into 1671
# Merging (1499, 816) into 1672
# Merging (1146, 293) into 1673
# Merging (39, 295) into 1674
# Merging (315, 329) into 1675
# Merging (307, 351) into 1676
# Merging (284, 271) into 1677
# Merging (112, 427) into 1678
# Merging (449, 294) into 1679
# Merging (309, 109) into 1680
# Merging (789, 740) into 1681
# Merging (352, 115) into 1682
# Merging (264, 377) into 1683
# Merging (258, 1038) into 1684
# Merging (339, 358) into 1685
# Merging (429, 261) into 1686
# Merging (378, 317) into 1687
# Merging (915, 335) into 1688
# Merging (442, 287) into 1689
# Merging (302, 114) into 1690
# Merging (442, 1268) into 1691
# Merging (432, 100) into 1692
# Merging (268, 109) into 1693
# Merging (99, 334) into 1694
# Merging (80, 276) into 1695
# Merging (114, 381) into 1696
# Merging (41, 267) into 1697
# Merging (337, 104) into 1698
# Merging (266, 366) into 1699
# Merging (756, 1362) into 1700
# Merging (285, 111) into 1701
# Merging (99, 107) into 1702
# Merging (1233, 642) into 1703
# Merging (774, 518) into 1704
# Merging (820, 1056) into 1705
# Merging (296, 408) into 1706
# Merging (269, 405) into 1707
# Merging (108, 276) into 1708
# Merging (881, 564) into 1709
# Merging (672, 109) into 1710
# Merging (440, 268) into 1711
# Merging (326, 277) into 1712
# Merging (117, 274) into 1713
# Merging (286, 97) into 1714
# Merging (266, 329) into 1715
# Merging (32, 364) into 1716
# Merging (414, 101) into 1717
# Merging (1434, 941) into 1718
# Merging (346, 294) into 1719
# Merging (316, 326) into 1720
# Merging (86, 650) into 1721
# Merging (390, 271) into 1722
# Merging (331, 376) into 1723
# Merging (356, 827) into 1724
# Merging (295, 122) into 1725
# Merging (807, 97) into 1726
# Merging (1477, 1194) into 1727
# Merging (795, 408) into 1728
# Merging (399, 108) into 1729
# Merging (1462, 666) into 1730
# Merging (330, 313) into 1731
# Merging (1041, 321) into 1732
# Merging (103, 104) into 1733
# Merging (958, 111) into 1734
# Merging (83, 302) into 1735
# Merging (98, 314) into 1736
# Merging (266, 1430) into 1737
# Merging (378, 261) into 1738
# Merging (262, 625) into 1739
# Merging (262, 696) into 1740
# Merging (315, 302) into 1741
# Merging (511, 111) into 1742
# Merging (283, 468) into 1743
# Merging (284, 107) into 1744
# Merging (287, 97) into 1745
# Merging (402, 114) into 1746
# Merging (264, 105) into 1747
# Merging (101, 326) into 1748
# Merging (304, 305) into 1749
# Merging (82, 65) into 1750
# Merging (949, 404) into 1751
# Merging (326, 510) into 1752
# Merging (86, 261) into 1753
# Merging (73, 65) into 1754
# Merging (337, 990) into 1755
# Merging (103, 300) into 1756
# Merging (582, 98) into 1757
# Merging (1339, 906) into 1758
# Merging (423, 300) into 1759
# Merging (117, 122) into 1760
# Merging (346, 1517) into 1761
# Merging (711, 557) into 1762
# Merging (550, 920) into 1763
# Merging (1197, 97) into 1764
# Merging (118, 334) into 1765
# Merging (912, 276) into 1766
# Merging (811, 465) into 1767
# Merging (100, 296) into 1768
# Merging (287, 575) into 1769
# Merging (84, 520) into 1770
# Merging (489, 327) into 1771
# Merging (391, 282) into 1772
# Merging (283, 432) into 1773
# Merging (803, 294) into 1774
# Merging (996, 494) into 1775
# Merging (1539, 452) into 1776
# Merging (84, 983) into 1777
# Merging (257, 510) into 1778
# Merging (84, 73) into 1779
# Merging (974, 276) into 1780
# Merging (500, 313) into 1781
# Merging (307, 312) into 1782
# Merging (103, 483) into 1783
# Merging (480, 101) into 1784
# Merging (605, 1600) into 1785
# Merging (66, 286) into 1786
# Merging (459, 1705) into 1787
# Merging (1163, 619) into 1788
# Merging (542, 1357) into 1789
# Merging (68, 271) into 1790
# Merging (855, 101) into 1791
# Merging (864, 111) into 1792
# Merging (84, 261) into 1793
# Merging (594, 98) into 1794
# Merging (118, 300) into 1795
# Merging (1516, 300) into 1796
# Merging (653, 261) into 1797
# Merging (298, 314) into 1798
# Merging (266, 97) into 1799
# Merging (333, 116) into 1800
# Merging (361, 97) into 1801
# Merging (310, 861) into 1802
# Merging (86, 333) into 1803
# Merging (594, 420) into 1804
# Merging (86, 502) into 1805
# Merging (451, 281) into 1806
# Merging (264, 502) into 1807
# Merging (515, 286) into 1808
# Merging (264, 545) into 1809
# Merging (1104, 415) into 1810
# Merging (286, 634) into 1811
# Merging (288, 874) into 1812
# Merging (288, 261) into 1813
# Merging (287, 332) into 1814
# Merging (1650, 305) into 1815
# Merging (615, 295) into 1816
# Merging (1063, 1581) into 1817
# Merging (84, 286) into 1818
# Merging (285, 648) into 1819
# Merging (881, 276) into 1820
# Merging (114, 808) into 1821
# Merging (396, 109) into 1822
# Merging (362, 104) into 1823
# Merging (270, 475) into 1824
# Merging (571, 360) into 1825
# Merging (736, 894) into 1826
# Merging (473, 109) into 1827
# Merging (93, 267) into 1828
# Merging (577, 103) into 1829
# Merging (266, 292) into 1830
# Merging (331, 1289) into 1831
# Merging (388, 99) into 1832
# Merging (341, 111) into 1833
# Merging (83, 298) into 1834
# Merging (681, 376) into 1835
# Merging (1664, 79) into 1836
# Merging (875, 408) into 1837
# Merging (595, 276) into 1838
# Merging (293, 114) into 1839
# Merging (72, 69) into 1840
# Merging (263, 529) into 1841
# Merging (974, 111) into 1842
# Merging (65, 114) into 1843
# Merging (1520, 1769) into 1844
# Merging (429, 1826) into 1845
# Merging (104, 310) into 1846
# Merging (270, 377) into 1847
# Merging (535, 493) into 1848
# Merging (258, 1249) into 1849
# Merging (459, 116) into 1850
# Merging (65, 68) into 1851
# Merging (543, 282) into 1852
# Merging (317, 669) into 1853
# Merging (637, 317) into 1854
# Merging (272, 846) into 1855
# Merging (553, 680) into 1856
# Merging (435, 312) into 1857
# Merging (563, 269) into 1858
# Merging (1473, 510) into 1859
# Merging (354, 276) into 1860
# Merging (258, 301) into 1861
# Merging (430, 1114) into 1862
# Merging (423, 111) into 1863
# Merging (283, 584) into 1864
# Merging (265, 326) into 1865
# Merging (739, 340) into 1866
# Merging (40, 579) into 1867
# Merging (76, 101) into 1868
# Merging (103, 908) into 1869
# Merging (1869, 271) into 1870
# Merging (337, 326) into 1871
# Merging (319, 108) into 1872
# Merging (463, 510) into 1873
# Merging (1345, 959) into 1874
# Merging (292, 265) into 1875
# Merging (288, 420) into 1876
# Merging (1263, 464) into 1877
# Merging (374, 303) into 1878
# Merging (111, 510) into 1879
# Merging (104, 269) into 1880
# Merging (86, 73) into 1881
# Merging (262, 1257) into 1882
# Merging (266, 314) into 1883
# Merging (1432, 715) into 1884
# Merging (1527, 268) into 1885
# Merging (842, 551) into 1886
# Merging (73, 86) into 1887
# Merging (796, 415) into 1888
# Merging (582, 112) into 1889
# Merging (258, 292) into 1890
# Merging (353, 97) into 1891
# Merging (288, 494) into 1892
# Merging (795, 640) into 1893
# Merging (99, 580) into 1894
# Merging (118, 296) into 1895
# Merging (258, 555) into 1896
# Merging (321, 108) into 1897
# Merging (1220, 452) into 1898
# Merging (273, 393) into 1899
# Merging (316, 100) into 1900
# Merging (556, 448) into 1901
# Merging (270, 468) into 1902
# Merging (39, 1582) into 1903
# Merging (45, 117) into 1904
# Merging (307, 100) into 1905
# Merging (1494, 496) into 1906
# Merging (370, 351) into 1907
# Merging (264, 114) into 1908
# Merging (68, 265) into 1909
# Merging (272, 1211) into 1910
# Merging (1587, 97) into 1911
# Merging (68, 303) into 1912
# Merging (79, 104) into 1913
# Merging (258, 514) into 1914
# Merging (470, 114) into 1915
# Merging (287, 408) into 1916
# Merging (1537, 960) into 1917
# Merging (271, 111) into 1918
# Merging (699, 446) into 1919
# Merging (1148, 490) into 1920
# Merging (270, 1711) into 1921
# Merging (524, 294) into 1922
# Merging (285, 573) into 1923
# Merging (283, 108) into 1924
# Merging (1571, 1147) into 1925
# Merging (434, 601) into 1926
# Merging (809, 122) into 1927
# Merging (45, 836) into 1928
# Merging (288, 362) into 1929
# Merging (66, 101) into 1930
# Merging (1716, 274) into 1931
# Merging (284, 101) into 1932
# Merging (65, 1844) into 1933
# Merging (259, 584) into 1934
# Merging (1746, 1079) into 1935
# Merging (83, 622) into 1936
# Merging (108, 268) into 1937
# Merging (427, 313) into 1938
# Merging (522, 294) into 1939
# Merging (362, 101) into 1940
# Merging (473, 528) into 1941
# Merging (284, 658) into 1942
# Merging (315, 287) into 1943
# Merging (264, 1377) into 1944
# Merging (259, 108) into 1945
# Merging (105, 446) into 1946
# ...
# Merging (400, 2561) into 4458
# Merging (283, 1419) into 4459
# Merging (577, 321) into 4460
# Merging (563, 293) into 4461
# Merging (789, 101) into 4462
# Merging (436, 555) into 4463
# Merging (1244, 727) into 4464
# Merging (965, 329) into 4465
# Merging (1799, 829) into 4466
# Merging (76, 559) into 4467
# Merging (389, 100) into 4468
# Merging (315, 117) into 4469
# Merging (605, 1441) into 4470
# Merging (361, 115) into 4471
# Merging (737, 420) into 4472
# Merging (2022, 115) into 4473
# Merging (1690, 740) into 4474
# Merging (711, 3449) into 4475
# Merging (3727, 2627) into 4476
# Merging (3685, 305) into 4477
# Merging (4477, 443) into 4478
# Merging (264, 427) into 4479
# Merging (102, 1034) into 4480
# Merging (2921, 312) into 4481
# Merging (262, 375) into 4482
# Merging (1510, 4089) into 4483
# Merging (33, 873) into 4484
# Merging (2814, 1551) into 4485
# Merging (4093, 3082) into 4486
# Merging (1749, 443) into 4487
# Merging (2927, 261) into 4488
# Merging (3810, 998) into 4489
# Merging (114, 2179) into 4490
# Merging (84, 2482) into 4491
# Merging (2090, 510) into 4492
# Merging (451, 571) into 4493
# Merging (1646, 117) into 4494
# Merging (2396, 276) into 4495
# Merging (78, 1030) into 4496
# Merging (2448, 408) into 4497
# Merging (3002, 405) into 4498
# Merging (1647, 425) into 4499
# Merging (2646, 372) into 4500
# Merging (2221, 2884) into 4501
# Merging (396, 120) into 4502
# Merging (470, 1894) into 4503
# Merging (103, 333) into 4504
# Merging (3099, 1264) into 4505
# Merging (1049, 685) into 4506
# Merging (1965, 313) into 4507
# Merging (2885, 314) into 4508
# Merging (284, 483) into 4509
# Merging (2490, 496) into 4510
# Merging (2758, 1555) into 4511
# Merging (2187, 122) into 4512
# Merging (2492, 69) into 4513
# Merging (378, 820) into 4514
# Merging (3274, 405) into 4515
# Merging (1675, 1272) into 4516
# Merging (337, 818) into 4517
# Merging (539, 1128) into 4518
# Merging (1511, 1696) into 4519
# Merging (2130, 1343) into 4520
# Merging (85, 110) into 4521
# Merging (448, 111) into 4522
# Merging (259, 567) into 4523
# Merging (77, 1323) into 4524
# Merging (77, 276) into 4525
# Merging (1542, 277) into 4526
# Merging (112, 468) into 4527
# Merging (460, 1455) into 4528
# Merging (2714, 300) into 4529
# Merging (1384, 269) into 4530
# Merging (4530, 330) into 4531
# Merging (695, 317) into 4532
# Merging (1097, 269) into 4533
# Merging (1741, 106) into 4534
# Merging (83, 1463) into 4535
# Merging (2301, 463) into 4536
# Merging (329, 349) into 4537
# Merging (3722, 491) into 4538
# Merging (1303, 1752) into 4539
# Merging (618, 281) into 4540
# Merging (287, 335) into 4541
# Merging (838, 468) into 4542
# Merging (283, 116) into 4543
# Merging (1453, 3994) into 4544
# Merging (258, 1366) into 4545
# Merging (324, 457) into 4546
# Merging (109, 284) into 4547
# Merging (102, 265) into 4548
# Merging (1666, 261) into 4549
# Merging (1258, 111) into 4550
# Merging (1073, 880) into 4551
# Merging (284, 1128) into 4552
# Merging (932, 389) into 4553
# Merging (285, 1152) into 4554
# Merging (3217, 366) into 4555
# Merging (1096, 269) into 4556
# Merging (114, 833) into 4557
# Merging (268, 100) into 4558
# Merging (2006, 884) into 4559
# Merging (306, 313) into 4560
# Merging (1155, 119) into 4561
# Merging (2169, 103) into 4562
# Merging (4367, 4168) into 4563
# Merging (390, 2205) into 4564
# Merging (2900, 3131) into 4565
# Merging (304, 284) into 4566
# Merging (1368, 268) into 4567
# Merging (436, 354) into 4568
# Merging (2903, 4276) into 4569
# Merging (391, 1151) into 4570
# Merging (2181, 97) into 4571
# Merging (401, 111) into 4572
# Merging (1442, 281) into 4573
# Merging (2049, 566) into 4574
# Merging (437, 540) into 4575
# Merging (266, 301) into 4576
# Merging (82, 1287) into 4577
# Merging (4114, 2094) into 4578
# Merging (425, 354) into 4579
# Merging (2599, 963) into 4580
# Merging (285, 448) into 4581
# Merging (33, 41) into 4582
# Merging (80, 101) into 4583
# Merging (410, 2613) into 4584
# Merging (102, 295) into 4585
# Merging (40, 69) into 4586
# Merging (691, 105) into 4587
# Merging (2754, 102) into 4588
# Merging (2488, 1145) into 4589
# Merging (283, 567) into 4590
# Merging (100, 364) into 4591
# Merging (105, 589) into 4592
# Merging (325, 269) into 4593
# Merging (2464, 622) into 4594
# Merging (606, 398) into 4595
# Merging (361, 116) into 4596
# Merging (339, 4126) into 4597
# Merging (4597, 71) into 4598
# Merging (429, 1663) into 4599
# Merging (1729, 472) into 4600
# Merging (72, 2683) into 4601
# Merging (388, 590) into 4602
# Merging (489, 295) into 4603
# Merging (663, 404) into 4604
# Merging (303, 3060) into 4605
# Merging (3129, 753) into 4606
# Merging (3763, 3223) into 4607
# Merging (273, 2485) into 4608
# Merging (1369, 302) into 4609
# Merging (577, 300) into 4610
# Merging (99, 314) into 4611
# Merging (67, 375) into 4612
# Merging (515, 79) into 4613
# Merging (45, 100) into 4614
# Merging (1738, 707) into 4615
# Merging (285, 724) into 4616
# Merging (2490, 295) into 4617
# Merging (83, 1285) into 4618
# Merging (93, 10) into 4619
# Merging (280, 101) into 4620
# Merging (65, 110) into 4621
# Merging (363, 104) into 4622
# Merging (582, 102) into 4623
# Merging (1667, 586) into 4624
# Merging (1424, 727) into 4625
# Merging (103, 559) into 4626
# Merging (965, 294) into 4627
# Merging (1107, 309) into 4628
# Merging (78, 827) into 4629
# Merging (4231, 2261) into 4630
# Merging (546, 472) into 4631
# Merging (583, 293) into 4632
# Merging (304, 1096) into 4633
# Merging (862, 2624) into 4634
# Merging (479, 116) into 4635
# Merging (603, 111) into 4636
# Merging (333, 1733) into 4637
# Merging (845, 2081) into 4638
# Merging (1109, 117) into 4639
# Merging (408, 100) into 4640
# Merging (370, 1897) into 4641
# Merging (1162, 119) into 4642
# Merging (4054, 65) into 4643
# Merging (4055, 1274) into 4644
# Merging (280, 265) into 4645
# Merging (1017, 614) into 4646
# Merging (350, 463) into 4647
# Merging (1915, 598) into 4648
# Merging (1977, 505) into 4649
# Merging (378, 405) into 4650
# Merging (659, 2787) into 4651
# Merging (578, 1318) into 4652
# Merging (498, 10) into 4653
# Merging (2852, 3068) into 4654
# Merging (33, 1078) into 4655
# Merging (709, 115) into 4656
# Merging (305, 623) into 4657
# Merging (2097, 640) into 4658
# Merging (388, 443) into 4659
# Merging (270, 693) into 4660
# Merging (462, 101) into 4661
# Merging (287, 598) into 4662
# Merging (259, 118) into 4663
# Merging (296, 580) into 4664
# Merging (3672, 1983) into 4665
# Merging (1710, 3584) into 4666
# Merging (606, 261) into 4667
# Merging (80, 1999) into 4668
# Merging (388, 122) into 4669
# Merging (458, 303) into 4670
# Merging (886, 121) into 4671
# Merging (1701, 111) into 4672
# Merging (933, 44) into 4673
# Merging (260, 108) into 4674
# Merging (118, 420) into 4675
# Merging (1006, 115) into 4676
# Merging (72, 713) into 4677
# Merging (39, 116) into 4678
# Merging (747, 281) into 4679
# Merging (260, 1455) into 4680
# Merging (266, 3351) into 4681
# Merging (346, 356) into 4682
# Merging (966, 1706) into 4683
# Merging (442, 296) into 4684
# Merging (2521, 296) into 4685
# Merging (2865, 117) into 4686
# Merging (65, 77) into 4687
# Merging (1958, 115) into 4688
# Merging (553, 1294) into 4689
# Merging (2077, 286) into 4690
# Merging (1544, 818) into 4691
# Merging (285, 744) into 4692
# Merging (1401, 267) into 4693
# Merging (2577, 1457) into 4694
# Merging (605, 475) into 4695
# Merging (511, 271) into 4696
# Merging (835, 310) into 4697
# Merging (365, 479) into 4698
# Merging (99, 302) into 4699
# Merging (258, 327) into 4700
# Merging (1186, 540) into 4701
# Merging (3260, 97) into 4702
# Merging (82, 97) into 4703
# Merging (97, 408) into 4704
# Merging (70, 362) into 4705
# Merging (578, 2700) into 4706
# Merging (429, 79) into 4707
# Merging (83, 1642) into 4708
# Merging (259, 112) into 4709
# Merging (675, 998) into 4710
# Merging (546, 1489) into 4711
# Merging (1643, 669) into 4712
# Merging (458, 558) into 4713
# Merging (3365, 381) into 4714
# Merging (3265, 827) into 4715
# Merging (1355, 3967) into 4716
# Merging (2868, 1606) into 4717
# Merging (1162, 567) into 4718
# Merging (1347, 277) into 4719
# Merging (434, 712) into 4720
# Merging (72, 333) into 4721
# Merging (100, 557) into 4722
# Merging (273, 633) into 4723
# Merging (264, 693) into 4724
# Merging (2336, 2760) into 4725
# Merging (288, 1360) into 4726
# Merging (82, 269) into 4727
# Merging (578, 504) into 4728
# Merging (65, 2163) into 4729
# Merging (32, 2194) into 4730
# Merging (70, 715) into 4731
# Merging (4310, 718) into 4732
# Merging (2448, 640) into 4733
# Merging (264, 969) into 4734
# Merging (1453, 276) into 4735
# Merging (357, 979) into 4736
# Merging (270, 105) into 4737
# Merging (1256, 333) into 4738
# Merging (32, 876) into 4739
# Merging (69, 84) into 4740
# Merging (481, 1759) into 4741
# Merging (4124, 558) into 4742
# Merging (267, 501) into 4743
# Merging (1835, 261) into 4744
# Merging (429, 529) into 4745
# Merging (285, 714) into 4746
# Merging (67, 79) into 4747
# Merging (303, 479) into 4748
# Merging (429, 2547) into 4749
# Merging (285, 1918) into 4750
# Merging (653, 286) into 4751
# Merging (1196, 715) into 4752
# Merging (112, 363) into 4753
# Merging (1529, 1452) into 4754
# Merging (99, 287) into 4755
# Merging (364, 109) into 4756
# Merging (524, 312) into 4757
# Merging (492, 4537) into 4758
# Merging (4330, 1621) into 4759
# Merging (2946, 920) into 4760
# Merging (953, 1065) into 4761
# Merging (364, 714) into 4762
# Merging (2417, 286) into 4763
# Merging (953, 404) into 4764
# Merging (2774, 830) into 4765
# Merging (1426, 265) into 4766
# Merging (467, 387) into 4767
# Merging (1498, 557) into 4768
# Merging (701, 300) into 4769
# Merging (321, 614) into 4770
# Merging (539, 2199) into 4771
# Merging (3119, 516) into 4772
# Merging (615, 1007) into 4773
# Merging (425, 265) into 4774
# Merging (3509, 120) into 4775
# Merging (364, 102) into 4776
# Merging (1064, 268) into 4777
# Merging (394, 141) into 4778
# Merging (509, 108) into 4779
# Merging (3122, 2088) into 4780
# Merging (270, 554) into 4781
# Merging (451, 2084) into 4782
# Merging (429, 622) into 4783
# Merging (1513, 673) into 4784
# Merging (1291, 309) into 4785
# Merging (3126, 334) into 4786
# Merging (287, 658) into 4787
# Merging (1176, 722) into 4788
# Merging (1176, 1141) into 4789
# Merging (264, 298) into 4790
# Merging (361, 351) into 4791
# Merging (3866, 2462) into 4792
# Merging (114, 284) into 4793
# Merging (410, 1635) into 4794
# Merging (708, 1147) into 4795
# Merging (3305, 531) into 4796
# Merging (382, 98) into 4797
# Merging (264, 282) into 4798
# Merging (76, 69) into 4799
# Merging (4174, 693) into 4800
# Merging (302, 707) into 4801
# Merging (638, 1070) into 4802
# Merging (302, 415) into 4803
# Merging (741, 101) into 4804
# Merging (272, 2266) into 4805
# Merging (539, 116) into 4806
# Merging (1333, 608) into 4807
# Merging (260, 2547) into 4808
# Merging (258, 1151) into 4809
# Merging (257, 406) into 4810
# Merging (809, 326) into 4811
# Merging (284, 117) into 4812
# Merging (748, 326) into 4813
# Merging (99, 960) into 4814
# Merging (1684, 715) into 4815
# Merging (3298, 265) into 4816
# Merging (1304, 405) into 4817
# Merging (100, 302) into 4818
# Merging (509, 2462) into 4819
# Merging (470, 620) into 4820
# Merging (3882, 1825) into 4821
# Merging (100, 540) into 4822
# Merging (264, 3861) into 4823
# Merging (266, 296) into 4824
# Merging (4031, 362) into 4825
# Merging (2091, 263) into 4826
# Merging (545, 557) into 4827
# Merging (3232, 300) into 4828
# Merging (889, 302) into 4829
# Merging (1651, 518) into 4830
# Merging (1287, 84) into 4831
# Merging (77, 4033) into 4832
# Merging (259, 116) into 4833
# Merging (471, 302) into 4834
# Merging (1381, 1602) into 4835
# Merging (899, 1131) into 4836
# Merging (1756, 332) into 4837
# Merging (1573, 265) into 4838
# Merging (566, 286) into 4839
# Merging (3037, 1976) into 4840
# Merging (378, 361) into 4841
# Merging (258, 715) into 4842
# Merging (270, 309) into 4843
# Merging (112, 313) into 4844
# Merging (388, 110) into 4845
# Merging (1146, 1718) into 4846
# Merging (2388, 389) into 4847
# Merging (275, 1506) into 4848
# Merging (3244, 3899) into 4849
# Merging (1275, 406) into 4850
# Merging (427, 326) into 4851
# Merging (511, 79) into 4852
# Merging (331, 289) into 4853
# Merging (2854, 381) into 4854
# Merging (2023, 309) into 4855
# Merging (82, 321) into 4856
# Merging (1512, 415) into 4857
# Merging (195, 138) into 4858
# Merging (2770, 830) into 4859
# Merging (3628, 468) into 4860
# Merging (2161, 598) into 4861
# Merging (1908, 371) into 4862
# Merging (272, 1707) into 4863
# Merging (294, 389) into 4864
# Merging (76, 3213) into 4865
# Merging (511, 309) into 4866
# Merging (505, 3728) into 4867
# Merging (117, 281) into 4868
# Merging (795, 423) into 4869
# Merging (1930, 98) into 4870
# Merging (730, 796) into 4871
# Merging (1605, 1158) into 4872
# Merging (270, 329) into 4873
# Merging (78, 101) into 4874
# Merging (1332, 1304) into 4875
# Merging (288, 454) into 4876
# Merging (1531, 389) into 4877
# Merging (3248, 1360) into 4878
# Merging (2993, 758) into 4879
# Merging (323, 1088) into 4880
# Merging (1260, 326) into 4881
# Merging (315, 554) into 4882
# Merging (72, 261) into 4883
# Merging (3779, 276) into 4884
# Merging (546, 888) into 4885
# Merging (341, 2180) into 4886
# Merging (99, 333) into 4887
# Merging (402, 4632) into 4888
# Merging (3495, 119) into 4889
# Merging (107, 115) into 4890
# Merging (639, 575) into 4891
# Merging (1386, 2012) into 4892
# Merging (341, 465) into 4893
# Merging (76, 2610) into 4894
# Merging (328, 1523) into 4895
# Merging (470, 100) into 4896
# Merging (4896, 1768) into 4897
# Merging (1433, 545) into 4898
# Merging (1073, 869) into 4899
# Merging (926, 1800) into 4900
# Merging (107, 1265) into 4901
# Merging (4901, 110) into 4902
# Merging (448, 97) into 4903
# Merging (77, 111) into 4904
# Merging (743, 2453) into 4905
# Merging (1184, 2717) into 4906
# Merging (790, 408) into 4907
# Merging (2044, 313) into 4908
# Merging (500, 463) into 4909
# Merging (539, 415) into 4910
# Merging (2409, 313) into 4911
# Merging (966, 115) into 4912
# Merging (97, 389) into 4913
# Merging (79, 68) into 4914
# Merging (110, 261) into 4915
# Merging (1867, 267) into 4916
# Merging (272, 2694) into 4917
# Merging (2575, 1311) into 4918
# Merging (719, 108) into 4919
# Merging (459, 408) into 4920
# Merging (39, 300) into 4921
# Merging (584, 115) into 4922
# Merging (72, 516) into 4923
# Merging (4618, 2289) into 4924
# Merging (272, 284) into 4925
# Merging (809, 401) into 4926
# Merging (266, 356) into 4927
# Merging (1739, 117) into 4928
# Merging (485, 309) into 4929
# Merging (76, 1274) into 4930
# Merging (595, 108) into 4931
# Merging (370, 1246) into 4932
# Merging (594, 3546) into 4933
# Merging (306, 642) into 4934
# Merging (304, 3175) into 4935
# Merging (1111, 1033) into 4936
# Merging (394, 180) into 4937
# Merging (4937, 110) into 4938
# Merging (259, 294) into 4939
# Merging (423, 3172) into 4940
# Merging (1473, 101) into 4941
# Merging (2044, 317) into 4942
# Merging (32, 2213) into 4943
# Merging (288, 2793) into 4944
# Merging (956, 544) into 4945
# Merging (97, 390) into 4946
# Merging (442, 1932) into 4947
# Merging (895, 3440) into 4948
# Merging (3937, 1304) into 4949
# Merging (445, 101) into 4950
# Merging (32, 829) into 4951
# Merging (341, 1299) into 4952
# Merging (3108, 846) into 4953
# Merging (45, 2959) into 4954
# Merging (429, 419) into 4955
# Merging (2578, 544) into 4956
# Merging (296, 893) into 4957
# Merging (1043, 102) into 4958
# Merging (434, 269) into 4959
# Merging (1550, 398) into 4960
# Merging (33, 44) into 4961
# Merging (307, 277) into 4962
# Merging (434, 286) into 4963
# Merging (1342, 269) into 4964
# Merging (1436, 4092) into 4965
# Merging (45, 45) into 4966
# Merging (2926, 100) into 4967
# Merging (331, 312) into 4968
# Merging (83, 371) into 4969
# Merging (2325, 295) into 4970
# Merging (2022, 716) into 4971
# Merging (3362, 2748) into 4972
# Merging (1207, 329) into 4973
# Merging (398, 654) into 4974
# Merging (4099, 390) into 4975
# Merging (2524, 483) into 4976
# Merging (2883, 108) into 4977
# Merging (66, 292) into 4978
# Merging (1315, 334) into 4979
# Merging (3470, 111) into 4980
# Merging (686, 97) into 4981
# Merging (470, 880) into 4982
# Merging (285, 1566) into 4983
# Merging (328, 1452) into 4984
# Merging (1170, 326) into 4985
# Merging (866, 276) into 4986
# Merging (114, 281) into 4987
# Merging (1064, 631) into 4988
# Merging (328, 269) into 4989
# Merging (2887, 1505) into 4990
# Merging (785, 479) into 4991
# Merging (258, 295) into 4992
# Merging (83, 1875) into 4993
# Merging (493, 695) into 4994
# Merging (430, 2940) into 4995
# Merging (71, 1750) into 4996
# Merging (835, 558) into 4997
# Merging (1162, 389) into 4998
# Merging (82, 302) into 4999

# %%
import pickle

with open('toks_vocab_5k.pkl', 'wb') as f:
    pickle.dump(toks.vocab, f)

# %%
with open('toks_vocab_5k.pkl', 'rb') as f:
    vocab = pickle.load(f)

print(vocab)
# Out:
# {0: b'\x00', 1: b'\x01', 2: b'\x02', 3: b'\x03', 4: b'\x04', 5: b'\x05', 6: b'\x06', 7: b'\x07', 8: b'\x08', 9: b'\t', 10: b'\n', 11: b'\x0b', 12: b'\x0c', 13: b'\r', 14: b'\x0e', 15: b'\x0f', 16: b'\x10', 17: b'\x11', 18: b'\x12', 19: b'\x13', 20: b'\x14', 21: b'\x15', 22: b'\x16', 23: b'\x17', 24: b'\x18', 25: b'\x19', 26: b'\x1a', 27: b'\x1b', 28: b'\x1c', 29: b'\x1d', 30: b'\x1e', 31: b'\x1f', 32: b' ', 33: b'!', 34: b'"', 35: b'#', 36: b'$', 37: b'%', 38: b'&', 39: b"'", 40: b'(', 41: b')', 42: b'*', 43: b'+', 44: b',', 45: b'-', 46: b'.', 47: b'/', 48: b'0', 49: b'1', 50: b'2', 51: b'3', 52: b'4', 53: b'5', 54: b'6', 55: b'7', 56: b'8', 57: b'9', 58: b':', 59: b';', 60: b'<', 61: b'=', 62: b'>', 63: b'?', 64: b'@', 65: b'A', 66: b'B', 67: b'C', 68: b'D', 69: b'E', 70: b'F', 71: b'G', 72: b'H', 73: b'I', 74: b'J', 75: b'K', 76: b'L', 77: b'M', 78: b'N', 79: b'O', 80: b'P', 81: b'Q', 82: b'R', 83: b'S', 84: b'T', 85: b'U', 86: b'V', 87: b'W', 88: b'X', 89: b'Y', 90: b'Z', 91: b'[', 92: b'\\', 93: b']', 94: b'^', 95: b'_', 96: b'`', 97: b'a', 98: b'b', 99: b'c', 100: b'd', 101: b'e', 102: b'f', 103: b'g', 104: b'h', 105: b'i', 106: b'j', 107: b'k', 108: b'l', 109: b'm', 110: b'n', 111: b'o', 112: b'p', 113: b'q', 114: b'r', 115: b's', 116: b't', 117: b'u', 118: b'v', 119: b'w', 120: b'x', 121: b'y', 122: b'z', 123: b'{', 124: b'|', 125: b'}', 126: b'~', 127: b'\x7f', 128: b'\x80', 129: b'\x81', 130: b'\x82', 131: b'\x83', 132: b'\x84', 133: b'\x85', 134: b'\x86', 135: b'\x87', 136: b'\x88', 137: b'\x89', 138: b'\x8a', 139: b'\x8b', 140: b'\x8c', 141: b'\x8d', 142: b'\x8e', 143: b'\x8f', 144: b'\x90', 145: b'\x91', 146: b'\x92', 147: b'\x93', 148: b'\x94', 149: b'\x95', 150: b'\x96', 151: b'\x97', 152: b'\x98', 153: b'\x99', 154: b'\x9a', 155: b'\x9b', 156: b'\x9c', 157: b'\x9d', 158: b'\x9e', 159: b'\x9f', 160: b'\xa0', 161: b'\xa1', 162: b'\xa2', 163: b'\xa3', 164: b'\xa4', 165: b'\xa5', 166: b'\xa6', 167: b'\xa7', 168: b'\xa8', 169: b'\xa9', 170: b'\xaa', 171: b'\xab', 172: b'\xac', 173: b'\xad', 174: b'\xae', 175: b'\xaf', 176: b'\xb0', 177: b'\xb1', 178: b'\xb2', 179: b'\xb3', 180: b'\xb4', 181: b'\xb5', 182: b'\xb6', 183: b'\xb7', 184: b'\xb8', 185: b'\xb9', 186: b'\xba', 187: b'\xbb', 188: b'\xbc', 189: b'\xbd', 190: b'\xbe', 191: b'\xbf', 192: b'\xc0', 193: b'\xc1', 194: b'\xc2', 195: b'\xc3', 196: b'\xc4', 197: b'\xc5', 198: b'\xc6', 199: b'\xc7', 200: b'\xc8', 201: b'\xc9', 202: b'\xca', 203: b'\xcb', 204: b'\xcc', 205: b'\xcd', 206: b'\xce', 207: b'\xcf', 208: b'\xd0', 209: b'\xd1', 210: b'\xd2', 211: b'\xd3', 212: b'\xd4', 213: b'\xd5', 214: b'\xd6', 215: b'\xd7', 216: b'\xd8', 217: b'\xd9', 218: b'\xda', 219: b'\xdb', 220: b'\xdc', 221: b'\xdd', 222: b'\xde', 223: b'\xdf', 224: b'\xe0', 225: b'\xe1', 226: b'\xe2', 227: b'\xe3', 228: b'\xe4', 229: b'\xe5', 230: b'\xe6', 231: b'\xe7', 232: b'\xe8', 233: b'\xe9', 234: b'\xea', 235: b'\xeb', 236: b'\xec', 237: b'\xed', 238: b'\xee', 239: b'\xef', 240: b'\xf0', 241: b'\xf1', 242: b'\xf2', 243: b'\xf3', 244: b'\xf4', 245: b'\xf5', 246: b'\xf6', 247: b'\xf7', 248: b'\xf8', 249: b'\xf9', 250: b'\xfa', 251: b'\xfb', 252: b'\xfc', 253: b'\xfd', 254: b'\xfe', 255: b'\xff', 256: b'  ', 257: b' a', 258: b' d', 259: b' e', 260: b' s', 261: b'er', 262: b' m', 263: b'qu', 264: b' c', 265: b'os', 266: b' t', 267: b'\n\n', 268: b'or', 269: b'es', 270: b' p', 271: b'as', 272: b' n', 273: b' o', 274: b'nt', 275: b' qu', 276: b'ar', 277: b'do', 278: b' que', 279: b'    ', 280: b'\xc3\xa3', 281: b'is', 282: b'\xc3\xa3o', 283: b' de', 284: b'in', 285: b' v', 286: b'em', 287: b'an', 288: b' f', 289: b'da', 290: b'..', 291: b',\n', 292: b'om', 293: b'\xc3\xa9', 294: b're', 295: b'ra', 296: b'en', 297: b'.\n\n', 298: b'ent', 299: b'.\n', 300: b'al', 301: b'um', 302: b'ei', 303: b'\xc3\xa1', 304: b' l', 305: b'im', 306: b' es', 307: b'on', 308: b' h', 309: b'ia', 310: b'am', 311: b'\xc3\xa7', 312: b'de', 313: b'to', 314: b'ro', 315: b' b', 316: b' me', 317: b'te', 318: b' \xc3\xa9', 319:  ...
